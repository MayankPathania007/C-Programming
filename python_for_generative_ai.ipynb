# %% [markdown]
# <a href="https://colab.research.google.com/github/MayankPathania007/C-Programming/blob/main/python_for_generative_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
x
# Out:
# 10

# %%
Y=20
Y
# Out:
# 20

# %%
my_sub="generative ai"
my_sun
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1830610239.py in <cell line: 0>()
#       1 my_sub="generative ai"
# ----> 2 my_sun
#
# NameError: name 'my_sun' is not defined

# %%
my_sub="generative ai"
my_sub

# %%
my_city="kangra"
my_city

# %%
mycollege="shoolini university"
mycollege
# Out:
# 'shoolini university'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x=1
type(x)
# Out:
# int

# %%
y=0.0
type(y)
# Out:
# float

# %%
z=3+4j
type(z)
# Out:
# complex

# %%
a=45
type(a)
# Out:
# int

# %%
#string---data in the form of text
a="solan"
type(a)
# Out:
# str

# %%
#boolean--it is used to store a value that is trur and false
x=True
type(x)
# Out:
# bool

# %%
y=False
type(Y)
# Out:
# int

# %%
y=False
type(y)
# Out:
# bool

# %%
#none--it is null value means nothing
e=None
type(e)
# Out:
# NoneType

# %%
#addition
2+2
# Out:
# 4

# %%
x=4
y=6
z=x+y
print(z)
# Out:
# 10

# %%
#subtraction
a=10
b=5
c=a-b
print(c)
# Out:
# 5

# %%
#multiplaction
a=40
b=54
c=a*b
print(c)
# Out:
# 2160

# %%
#division
a=10
b=5
c=a/b
print(c)
# Out:
# 2.0

# %%
#expontiation
a=2
b=3
c=a**b
print(c)
# Out:
# 8

# %%
#floor division--return the result in whole number
7//2
# Out:
# 3

# %%
7.0//2
# Out:
# 3.0

# %%
#modulus--the output is remainder
12%21
# Out:
# 12

# %%
#upper()--this meathod is used to convert into uppercase
my_sub="python"
my_sub.upper()
# Out:
# 'PYTHON'

# %%
#count()--this meathod count particular charecter charecther in string
my_string="machine learning"
my_string.count('a')
# Out:
# 2

# %%
my_list=[78,89,23,45,46]
type(my_list)
# Out:
# list

# %%
from pickle import TRUE
mixed_list=[23,3.14,"apple",True,None]
type(mixed_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [78, 89, 23, 45, 46]

# %%
#find the length of the list
len(my_list)
# Out:
# 5

# %%
my_list=[78,89,23,34,10]
print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[3])
print(my_list[4])
# Out:
# 78
# 89
# 23
# 34
# 10

# %%
#negative indexing
my_list=[78,89,23,34,10]
print(my_list[-1])
print(my_list[-2])
print(my_list[-3])
print(my_list[-4])
print(my_list[-5])
# Out:
# 10
# 34
# 23
# 89
# 78

# %%
my_list=[2,3,7,1,4,5]
my_list[0:5]
# Out:
# [2, 3, 7, 1, 4]

# %%
my_list[0:]
# Out:
# [2, 3, 7, 1, 4, 5]

# %%
my_list[:5]
# Out:
# [2, 3, 7, 1, 4]

# %%
my_list[: : -1]
# Out:
# [5, 4, 1, 7, 3, 2]

# %%
#function in list
#min()--return the minimum number of the list
my_list=[98,34,56,45,12]
min(my_list)
# Out:
# 12

# %%
#max()--return maximum number of the list
max(my_list)
# Out:
# 98

# %%
my_list
# Out:
# [98, 34, 56, 45, 12]

# %%
#sum()--return addition of all item of the list
sum(my_list)
# Out:
# 245

# %%
#sorted()--this function arrange list increasing or decreasing order
list1=[9,7,12,4,8,3]
sorted(list1,reverse=True)
# Out:
# [12, 9, 8, 7, 4, 3]

# %%
list1
# Out:
# [9, 7, 12, 4, 8, 3]

# %%
#append()--this method add item end of the list and take item as argumen
my_list=[98,87,65,34]
print(my_list)
my_list.append(100)
print(my_list)
# Out:
# [98, 87, 65, 34]
# [98, 87, 65, 34, 100]

# %%
my_list
# Out:
# [98, 87, 65, 34, 100]

# %%
my_list[2]
print(my_list)
# Out:
# [98, 87, 65, 34, 100]

# %%
#extend()--this meathod merge a list into another list
list1=[90,78,65]
list2=[56,65,33]
list1.extend(list2)
print(list1)
# Out:
# [90, 78, 65, 56, 65, 33]

# %%
#pop()--this method remove item from the list,take index as arguement
my_list=[34,56,87,98,57]
my_list.pop()
# Out:
# 57

# %%
#remove()--this method remove item of the list,take item as argument
list1=[67,76,35,67,85,87]
list1.remove(35)
list1
# Out:
# [67, 76, 67, 85, 87]

# %%
#reverse()--this method reverse the list
my_list=[45,65,87,35]
my_list.reverse()
print(my_list)
# Out:
# [35, 87, 65, 45]

# %%
#dictionary
my_dict = {"name":"mayank","college":"shoolini university"}
type(my_dict)
# Out:
# dict
